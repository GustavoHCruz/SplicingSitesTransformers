# %%
import pandas as pd

from llms.exin_classifier.gpt import ExInClassifierGPT
from schemas.train_params import TrainParams

# %%
df = pd.read_csv("data/ExIn-GPT.csv", keep_default_na=False)

# %%
llm = ExInClassifierGPT(
  checkpoint="gpt2"
)

# %%
llm.load_data(
  data={
    "sequence": df["sequence"][:30000].to_list(),
    "target": df["target"][:30000].to_list(),
    "organism": df["organism"][:30000].to_list(),
    "gene": df["gene"][:30000].to_list(),
    "before": df["flankBefore"][:30000].to_list(),
    "after": df["flankAfter"][:30000].to_list()
	}
)

# %%
llm.train(
  params=TrainParams(
    epochs=1,
    batch_size=1,
    gradient_accumulation=1,
    lr=2e-5
	)
)
# Out:
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='30000' max='30000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30000/30000 44:54, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.253300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.074300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.074900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.032200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.014400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.037500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.022300</td>
#     </tr>
#     <tr>
#       <td>4000</td>
# ...

# %%
llm.save_pretrained("./exin-30k-gpt")
# Out:
# 2025-08-24 17:57:24,220 - INFO - Attempting to save model at './exin-30k-gpt'
